# %% [markdown]
# # Table of contents
# ## 01 Setting up
# ## 02 Data cleaning
# ## 03 EDA

# %% [markdown]
# # 01 Setting up

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import os

# %%
# setting up path
path = r"C:\Users\Anwender\Documents\10-2023 Happiness Project\02 Data"

# %%
# importing datasets from 2015-2019
df15 = pd.read_csv(os.path.join(path, "Original Data", "2015.csv"))
df16 = pd.read_csv(os.path.join(path, "Original Data", "2016.csv"))
df17 = pd.read_csv(os.path.join(path, "Original Data", "2017.csv"))
df18 = pd.read_csv(os.path.join(path, "Original Data", "2018.csv"))
df19 = pd.read_csv(os.path.join(path, "Original Data", "2019.csv"))

# %% [markdown]
# # 02 Data cleaning

# %% [markdown]
# ## Exploring df15

# %%
df15
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df15.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df15.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
# dropping Standard Error and Dystopia Residual columns
df15=df15.drop(columns=["Standard Error", "Dystopia Residual"])

# %%
df15.shape
# Out:
# (158, 10)

# %%
df15.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
# adding Year column for df15 for later merge of dataframes
df15["Year"]="2015"

# %%
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Year                           158 non-null    object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 13.7+ KB

# %%
#changing dtype of Year to int64
df15["Year"]=df15["Year"].astype("int64")

# %%
df15.dtypes["Year"]
# Out:
# dtype('int64')

# %%
df15.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      158.000000       158.000000                158.000000  158.000000
# mean        79.493671         5.375734                  0.846137    0.991046
# std         45.754363         1.145010                  0.403121    0.272369
# min          1.000000         2.839000                  0.000000    0.000000
# 25%         40.250000         4.526000                  0.545808    0.856823
# 50%         79.500000         5.232500                  0.910245    1.029510
# 75%        118.750000         6.243750                  1.158448    1.214405
# max        158.000000         7.587000                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %%
df15.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Year                             0
# dtype: int64

# %% [markdown]
# No missing values found.

# %%
df15.isna().any()
# Out:
# Country                          False
# Region                           False
# Happiness Rank                   False
# Happiness Score                  False
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Year                             False
# dtype: bool

# %% [markdown]
# No N/A values found.

# %%
df15_dups = df15[df15.duplicated()]
df15_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Year]
# Index: []

# %% [markdown]
# No duplicates found.

# %% [markdown]
# # Exploring df16

# %%
df16
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %% [markdown]
# There are only 157 countries listed as opposed to 158 from df15.

# %%
df16.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# ...

# %%
df16.tail(10)
# Out:
#          Country                           Region  Happiness Rank  \
# 147   Madagascar               Sub-Saharan Africa             148
# 148     Tanzania               Sub-Saharan Africa             149
# 149      Liberia               Sub-Saharan Africa             150
# 150       Guinea               Sub-Saharan Africa             151
# 151       Rwanda               Sub-Saharan Africa             152
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 147            3.695                      3.621                      3.769
# 148            3.666                      3.561                      3.771
# ...

# %%
#dropping columns Lower Confidence Interval, Upper Confidence Interval and Dystopia Residual
df16=df16.drop(columns=["Lower Confidence Interval", "Upper Confidence Interval","Dystopia Residual"])

# %%
df16.shape
# Out:
# (157, 10)

# %%
df16.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
#adding Year column for df16 for later merge
df16["Year"]="2016"

# %%
df16["Year"]=df16["Year"].astype("int64")

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Economy (GDP per Capita)       157 non-null    float64
#  5   Family                         157 non-null    float64
#  6   Health (Life Expectancy)       157 non-null    float64
#  7   Freedom                        157 non-null    float64
#  8   Trust (Government Corruption)  157 non-null    float64
#  9   Generosity                     157 non-null    float64
#  10  Year                           157 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.6+ KB

# %%
df16.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      157.000000       157.000000                157.000000  157.000000
# mean        78.980892         5.382185                  0.953880    0.793621
# std         45.466030         1.141674                  0.412595    0.266706
# min          1.000000         2.905000                  0.000000    0.000000
# 25%         40.000000         4.404000                  0.670240    0.641840
# 50%         79.000000         5.314000                  1.027800    0.841420
# 75%        118.000000         6.269000                  1.279640    1.021520
# max        157.000000         7.526000                  1.824270    1.183260
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                157.000000  157.000000                     157.000000
# mean                   0.557619    0.370994                       0.137624
# ...

# %%
#checking for missing values
df16.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Year                             0
# dtype: int64

# %% [markdown]
# No missing values found.

# %%
#checking for duplicates
df16_dups = df16[df16.duplicated()]
df16_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Year]
# Index: []

# %% [markdown]
# No duplicates found.

# %%
# looking for missing overlap in dataframes
df16['Country'].isin(df15['Country']).value_counts()
# Out:
# True     151
# False      6
# Name: Country, dtype: int64

# %%
# displaying rows that are not included in df15
false_rows =~df16['Country'].isin(df15['Country'])
print (df16[false_rows])
# Out:
#                Country                       Region  Happiness Rank  \
# 14         Puerto Rico  Latin America and Caribbean              15
# 51              Belize  Latin America and Caribbean              52
# 75             Somalia           Sub-Saharan Africa              76
# 96   Somaliland Region           Sub-Saharan Africa              97
# 112            Namibia           Sub-Saharan Africa             113
# 142        South Sudan           Sub-Saharan Africa             143
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 14             7.039                   1.35943  1.08113
# 51             5.956                   0.87616  0.68655
# 75             5.440                   0.00000  0.33613
# 96             5.057                   0.25558  0.75862
# 112            4.574                   0.93287  0.70362
# 142            3.832                   0.39394  0.18519
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# Since not every country will get surveyed every year, it is possible that there will be missing values between df15 and df16. I will decide what to do with them once I have cleaned the following dataframes from 2017-2019.

# %%
# merging df15 and df16:
frames_15_16 = [df15,df16]
df_15_16=pd.concat(frames_15_16)

df_15_16
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %% [markdown]
# # Exploring df17

# %%
df17
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %% [markdown]
# There are 155 countries listed as opposed to the previous dfs.
# The columns need renaming to keep data uniform, the Region column is missing.

# %%
df17.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
df17.tail(10)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 145                     Yemen             146            3.593      3.692750
# 146               South Sudan             147            3.591      3.725539
# 147                   Liberia             148            3.533      3.653756
# 148                    Guinea             149            3.507      3.584428
# 149                      Togo             150            3.495      3.594038
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 145     3.493250                  0.591683  0.935382
# ...

# %%
#dropping columns Lower Confidence Interval, Upper Confidence Interval and Dystopia Residual
df17=df17.drop(columns=["Whisker.high", "Whisker.low","Dystopia.Residual"])

# %%
df17.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score',
#        'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
#        'Freedom', 'Generosity', 'Trust..Government.Corruption.'],
#       dtype='object')

# %%
#renaming columns for uniformity
df17.rename(columns={"Happiness.Rank":"Happiness Rank", 
                     "Happiness.Score":"Happiness Score", 
                     "Economy..GDP.per.Capita.":"Economy (GDP per Capita)", 
                     "Health..Life.Expectancy.":"Health (Life Expectancy)", 
                     "Trust..Government.Corruption.":"Trust (Government Corruption)"}, inplace = True)

# %%
df17.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
#adding Year column for df17 for later merge
df17["Year"]="2017"

# %%
#changing dtype to int64
df17["Year"]=df17["Year"].astype("int64")

# %%
#value counts for Region column of df15:
df15["Region"].value_counts(dropna=False)
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
# adding Region column to df17 for uniformity
df17["Region"] = pd.Series([], dtype=object)
df17["Region"] = df17["Country"].map(dict(zip(df_15_16["Country"], df_15_16["Region"]))).fillna(df17.Region)

df17.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health (Life Expectancy)   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust (Government Corruption)  Year          Region
# 0                       0.315964  2017  Western Europe
# ...

# %%
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness Rank                 155 non-null    int64
#  2   Happiness Score                155 non-null    float64
#  3   Economy (GDP per Capita)       155 non-null    float64
#  4   Family                         155 non-null    float64
#  5   Health (Life Expectancy)       155 non-null    float64
#  6   Freedom                        155 non-null    float64
#  7   Generosity                     155 non-null    float64
#  8   Trust (Government Corruption)  155 non-null    float64
#  9   Year                           155 non-null    int64
#  10  Region                         153 non-null    object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.4+ KB

# %%
df17.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      155.000000       155.000000                155.000000  155.000000
# mean        78.000000         5.354019                  0.984718    1.188898
# std         44.888751         1.131230                  0.420793    0.287263
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         39.500000         4.505500                  0.663371    1.042635
# 50%         78.000000         5.279000                  1.064578    1.253918
# 75%        116.500000         6.101500                  1.318027    1.414316
# max        155.000000         7.537000                  1.870766    1.610574
#
#        Health (Life Expectancy)     Freedom  Generosity  \
# count                155.000000  155.000000  155.000000
# mean                   0.551341    0.408786    0.246883
# std                    0.237073    0.149997    0.134780
# ...

# %%
df17.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Year                             0
# Region                           2
# dtype: int64

# %%
# viewing rows of df17 with missing variables in Region column:
df17_nan = df17[df17["Region"].isnull() == True]
df17_nan
# Out:
#                      Country  Happiness Rank  Happiness Score  \
# 32  Taiwan Province of China              33            6.422
# 70   Hong Kong S.A.R., China              71            5.472
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 32                  1.433627  1.384565                  0.793984  0.361467
# 70                  1.551675  1.262791                  0.943062  0.490969
#
#     Generosity  Trust (Government Corruption)  Year Region
# 32    0.258360                       0.063829  2017    NaN
# 70    0.374466                       0.293934  2017    NaN

# %% [markdown]
# These countries either weren't included in the survey data of 2015/16 or they were renamed afterwards, therefore it's difficult to match up the country names. To keep the analysis simple without any political intentions, I will rename "Taiwan Province of China" to "Taiwan" and "Hong Kong S.A.R., China" to "China".

# %%
#renaming values for uniformity and filling Region column
df17 = df17.replace(["Taiwan Province of China"], "Taiwan")
df17 = df17.replace(["Hong Kong S.A.R., China"], "Hong Kong")
df17["Region"] = pd.Series([], dtype=object)
df17["Region"] = df17["Country"].map(dict(zip(df_15_16["Country"], df_15_16["Region"]))).fillna(df17.Region)

df17.loc[df17["Country"].isin(["Taiwan", "Hong Kong"])]
# Out:
#       Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 32     Taiwan              33            6.422                  1.433627
# 70  Hong Kong              71            5.472                  1.551675
#
#       Family  Health (Life Expectancy)   Freedom  Generosity  \
# 32  1.384565                  0.793984  0.361467    0.258360
# 70  1.262791                  0.943062  0.490969    0.374466
#
#     Trust (Government Corruption)  Year        Region
# 32                       0.063829  2017  Eastern Asia
# 70                       0.293934  2017  Eastern Asia

# %%
# checking for missing values
df17.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Year                             0
# Region                           0
# dtype: int64

# %% [markdown]
# No Missing values found.

# %%
#checking for duplicates
df17_dups = df17[df17.duplicated()]
df17_dups
# Out:
# Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Year, Region]
# Index: []

# %% [markdown]
# No duplicates found.

# %% [markdown]
# # Exploring df18

# %%
df18.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %%
df18.tail(10)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 146           147                    Malawi  3.587           0.186
# 147           148                     Haiti  3.582           0.315
# 148           149                   Liberia  3.495           0.076
# 149           150                     Syria  3.462           0.689
# 150           151                    Rwanda  3.408           0.332
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 146           0.541                    0.306                         0.531
# 147           0.714                    0.289                         0.025
# ...

# %% [markdown]
# There are countries missing in this df compared to df15 as well. There is a need to rename the columns, to add columns Region and Year as well.

# %%
#renaming columns for uniformity
df18.rename(columns={"Overall rank":"Happiness Rank", 
                     "Country or region":"Country", 
                     "Score":"Happiness Score",
                     "GDP per capita":"Economy (GDP per Capita)", 
                     "Social support":"Family",
                     "Healthy life expectancy":"Health (Life Expectancy)",
                     "Freedom to make life choices":"Freedom",
                     "Perceptions of corruption":"Trust (Government Corruption)"}, inplace = True)
df18.columns
# Out:
# Index(['Happiness Rank', 'Country', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
#adding Year column for df18 for later merge
df18["Year"]="2018"
df18["Year"]=df18["Year"].astype("int64")

# %%
# adding Region column to df18 for uniformity
df18["Region"] = pd.Series([], dtype=object)
df18["Region"] = df18["Country"].map(dict(zip(df_15_16["Country"], df_15_16["Region"]))).fillna(df18.Region)

df18.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.592                     0.874    0.681       0.202
# 1   1.582                     0.861    0.686       0.286
# 2   1.590                     0.868    0.683       0.284
# 3   1.644                     0.914    0.677       0.353
# 4   1.549                     0.927    0.660       0.256
#
#    Trust (Government Corruption)  Year          Region
# 0                          0.393  2018  Western Europe
# 1                          0.340  2018  Western Europe
# ...

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Rank                 156 non-null    int64
#  1   Country                        156 non-null    object
#  2   Happiness Score                156 non-null    float64
#  3   Economy (GDP per Capita)       156 non-null    float64
#  4   Family                         156 non-null    float64
#  5   Health (Life Expectancy)       156 non-null    float64
#  6   Freedom                        156 non-null    float64
#  7   Generosity                     156 non-null    float64
#  8   Trust (Government Corruption)  155 non-null    float64
#  9   Year                           156 non-null    int64
#  10  Region                         154 non-null    object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
df18.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      156.000000       156.000000                156.000000  156.000000
# mean        78.500000         5.375917                  0.891449    1.213237
# std         45.177428         1.119506                  0.391921    0.302372
# min          1.000000         2.905000                  0.000000    0.000000
# 25%         39.750000         4.453750                  0.616250    1.066750
# 50%         78.500000         5.378000                  0.949500    1.255000
# 75%        117.250000         6.168500                  1.197750    1.463000
# max        156.000000         7.632000                  2.096000    1.644000
#
#        Health (Life Expectancy)     Freedom  Generosity  \
# count                156.000000  156.000000  156.000000
# mean                   0.597346    0.454506    0.181006
# std                    0.247579    0.162424    0.098471
# ...

# %%
#checking for missing values
df18.isnull().sum()
# Out:
# Happiness Rank                   0
# Country                          0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    1
# Year                             0
# Region                           2
# dtype: int64

# %%
# viewing rows of df18 with missing variables in Region column:
df18_nan = df18[df18["Region"].isnull() == True]
df18_nan
# Out:
#     Happiness Rank            Country  Happiness Score  \
# 37              38  Trinidad & Tobago            6.192
# 57              58    Northern Cyprus            5.835
#
#     Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 37                     1.223   1.492                     0.564    0.575
# 57                     1.229   1.211                     0.909    0.495
#
#     Generosity  Trust (Government Corruption)  Year Region
# 37       0.171                          0.019  2018    NaN
# 57       0.179                          0.154  2018    NaN

# %%
df15.loc[df15["Country"].isin(["Trinidad","Tobago", "Trinidad and Tobago"])]
# Out:
#                 Country                       Region  Happiness Rank  \
# 40  Trinidad and Tobago  Latin America and Caribbean              41
#
#     Happiness Score  Economy (GDP per Capita)   Family  \
# 40            6.168                   1.21183  1.18354
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 40                   0.61483  0.55884                         0.0114
#
#     Generosity  Year
# 40     0.31844  2015

# %%
#renaming values for uniformity and filling Region column
df18 = df18.replace(["Trinidad & Tobago"], "Trinidad and Tobago")
df18["Region"] = pd.Series([], dtype=object)
df18["Region"] = df18["Country"].map(dict(zip(df_15_16["Country"], df_15_16["Region"]))).fillna(df18.Region)

df18.loc[df18["Country"].isin(["Trinidad and Tobago"])]
# Out:
#     Happiness Rank              Country  Happiness Score  \
# 37              38  Trinidad and Tobago            6.192
#
#     Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 37                     1.223   1.492                     0.564    0.575
#
#     Generosity  Trust (Government Corruption)  Year  \
# 37       0.171                          0.019  2018
#
#                          Region
# 37  Latin America and Caribbean

# %%
df18.loc[df18["Country"].isin (["Cyprus", "Northern Cyprus"])]
# Out:
#     Happiness Rank          Country  Happiness Score  \
# 57              58  Northern Cyprus            5.835
# 60              61           Cyprus            5.762
#
#     Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 57                     1.229   1.211                     0.909    0.495
# 60                     1.229   1.191                     0.909    0.423
#
#     Generosity  Trust (Government Corruption)  Year          Region
# 57       0.179                          0.154  2018             NaN
# 60       0.202                          0.035  2018  Western Europe

# %% [markdown]
# Since Northern Cyprus wasn't included in the previous df (and it's not internationally recognized to be independent from Cyprus aside from Turkey), I will remove the row with Northern Cyprus.

# %%
#checking for missing values
df18=df18.dropna()
df18.isnull().sum()
# Out:
# Happiness Rank                   0
# Country                          0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Year                             0
# Region                           0
# dtype: int64

# %%
#checking for duplicates
df18_dups = df18[df18.duplicated()]
df18_dups
# Out:
# Empty DataFrame
# Columns: [Happiness Rank, Country, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Year, Region]
# Index: []

# %% [markdown]
# No duplicates found.

# %% [markdown]
# # Exploring df19

# %%
df19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df19.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %% [markdown]
# Again, this df also needs renaming of columns, addition of Year and Region columns.

# %%
#renaming columns for uniformity
df19.rename(columns={"Overall rank":"Happiness Rank", 
                     "Country or region":"Country", 
                     "Score":"Happiness Score",
                     "GDP per capita":"Economy (GDP per Capita)", 
                     "Social support":"Family",
                     "Healthy life expectancy":"Health (Life Expectancy)",
                     "Freedom to make life choices":"Freedom",
                     "Perceptions of corruption":"Trust (Government Corruption)"}, inplace = True)
df19.columns
# Out:
# Index(['Happiness Rank', 'Country', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
#adding Year column for df19 for later merge
df19["Year"]="2019"
df19["Year"]=df19["Year"].astype("int64")

# %%
# adding Region column to df19 for uniformity
df19["Region"] = pd.Series([], dtype=object)
df19["Region"] = df19["Country"].map(dict(zip(df_15_16["Country"], df_15_16["Region"]))).fillna(df19.Region)

df19.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.587                     0.986    0.596       0.153
# 1   1.573                     0.996    0.592       0.252
# 2   1.582                     1.028    0.603       0.271
# 3   1.624                     1.026    0.591       0.354
# 4   1.522                     0.999    0.557       0.322
#
#    Trust (Government Corruption)  Year          Region
# 0                          0.393  2019  Western Europe
# 1                          0.410  2019  Western Europe
# ...

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Rank                 156 non-null    int64
#  1   Country                        156 non-null    object
#  2   Happiness Score                156 non-null    float64
#  3   Economy (GDP per Capita)       156 non-null    float64
#  4   Family                         156 non-null    float64
#  5   Health (Life Expectancy)       156 non-null    float64
#  6   Freedom                        156 non-null    float64
#  7   Generosity                     156 non-null    float64
#  8   Trust (Government Corruption)  156 non-null    float64
#  9   Year                           156 non-null    int64
#  10  Region                         152 non-null    object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
df19.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      156.000000       156.000000                156.000000  156.000000
# mean        78.500000         5.407096                  0.905147    1.208814
# std         45.177428         1.113120                  0.398389    0.299191
# min          1.000000         2.853000                  0.000000    0.000000
# 25%         39.750000         4.544500                  0.602750    1.055750
# 50%         78.500000         5.379500                  0.960000    1.271500
# 75%        117.250000         6.184500                  1.232500    1.452500
# max        156.000000         7.769000                  1.684000    1.624000
#
#        Health (Life Expectancy)     Freedom  Generosity  \
# count                156.000000  156.000000  156.000000
# mean                   0.725244    0.392571    0.184846
# std                    0.242124    0.143289    0.095254
# ...

# %%
#checking for missing values
df19.isnull().sum()
# Out:
# Happiness Rank                   0
# Country                          0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Year                             0
# Region                           4
# dtype: int64

# %%
# viewing rows of df18 with missing variables in Region column:
df19_nan = df19[df19["Region"].isnull() == True]
df19_nan
# Out:
#      Happiness Rank            Country  Happiness Score  \
# 38               39  Trinidad & Tobago            6.192
# 63               64    Northern Cyprus            5.718
# 83               84    North Macedonia            5.274
# 119             120             Gambia            4.516
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 38                      1.231   1.477                     0.713    0.489
# 63                      1.263   1.252                     1.042    0.417
# 83                      0.983   1.294                     0.838    0.345
# 119                     0.308   0.939                     0.428    0.382
#
#      Generosity  Trust (Government Corruption)  Year Region
# 38        0.185                          0.016  2019    NaN
# 63        0.191                          0.162  2019    NaN
# 83        0.185                          0.034  2019    NaN
# 119       0.269                          0.167  2019    NaN

# %%
df15.loc[df15["Country"].isin(["Macedonia", "Republic of Gambia", "The Gambia"])]
# Out:
#       Country                      Region  Happiness Rank  Happiness Score  \
# 92  Macedonia  Central and Eastern Europe              93            5.007
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 92                   0.91851  1.00232                   0.73545  0.33457
#
#     Trust (Government Corruption)  Generosity  Year
# 92                        0.05327     0.22359  2015

# %% [markdown]
# Since 2018, the region formerly known as Macedonia was recognized to be the Republic of Macedonia, which recognizes to have different history and cultures from the latter when both countries are being talked about.
# For simplification and ,by any means, without any political intentions, I will change the name the Macedonia.

# %%
#rename Trinidad& Tobago to Trinidad and Tobago and Macedonia to North Macedonia
df19 = df19.replace(["Trinidad & Tobago"], "Trinidad and Tobago")
df19 = df19.replace(["North Macedonia"], "Macedonia")
df19["Region"] = pd.Series([], dtype=object)
df19["Region"] = df19["Country"].map(dict(zip(df_15_16["Country"], df_15_16["Region"]))).fillna(df19.Region)

df19.loc[df19["Country"].isin(["Trinidad and Tobago", "Macedonia"])]
# Out:
#     Happiness Rank              Country  Happiness Score  \
# 38              39  Trinidad and Tobago            6.192
# 83              84            Macedonia            5.274
#
#     Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 38                     1.231   1.477                     0.713    0.489
# 83                     0.983   1.294                     0.838    0.345
#
#     Generosity  Trust (Government Corruption)  Year  \
# 38       0.185                          0.016  2019
# 83       0.185                          0.034  2019
#
#                          Region
# 38  Latin America and Caribbean
# 83   Central and Eastern Europe

# %%
df15.loc[df15["Region"].isin (["Middle East and Northern Africa", "Sub-Saharan Africa"])]
# Out:
#                       Country                           Region  \
# 10                     Israel  Middle East and Northern Africa
# 19       United Arab Emirates  Middle East and Northern Africa
# 21                       Oman  Middle East and Northern Africa
# 27                      Qatar  Middle East and Northern Africa
# 34               Saudi Arabia  Middle East and Northern Africa
# 38                     Kuwait  Middle East and Northern Africa
# 48                    Bahrain  Middle East and Northern Africa
# 62                      Libya  Middle East and Northern Africa
# 67                    Algeria  Middle East and Northern Africa
# 70                  Mauritius               Sub-Saharan Africa
# 75                     Turkey  Middle East and Northern Africa
# 77                    Nigeria               Sub-Saharan Africa
# 81                     Jordan  Middle East and Northern Africa
# 84                     Zambia               Sub-Saharan Africa
# ...

# %%
#dropping 2 countries
df19 = df19.dropna()
df19.isnull().sum()
# Out:
# Happiness Rank                   0
# Country                          0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Year                             0
# Region                           0
# dtype: int64

# %%
#checking for duplicates
df19_dups = df19[df19.duplicated()]
df19_dups
# Out:
# Empty DataFrame
# Columns: [Happiness Rank, Country, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Year, Region]
# Index: []

# %% [markdown]
# No duplicates found.

# %% [markdown]
# # Merging df15-df19 into one

# %%
# "merging" all dataframes by concatenating them:
frames = [df_15_16,df17,df18,df19]
df_concat = pd.concat(frames)

# %%
df_concat
# Out:
#                       Country              Region  Happiness Rank  \
# 0                 Switzerland      Western Europe               1
# 1                     Iceland      Western Europe               2
# 2                     Denmark      Western Europe               3
# 3                      Norway      Western Europe               4
# 4                      Canada       North America               5
# ..                        ...                 ...             ...
# 151                    Rwanda  Sub-Saharan Africa             152
# 152                  Tanzania  Sub-Saharan Africa             153
# 153               Afghanistan       Southern Asia             154
# 154  Central African Republic  Sub-Saharan Africa             155
# 155               South Sudan  Sub-Saharan Africa             156
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %%
df_concat.shape
# Out:
# (778, 11)

# %%
df_concat.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')

# %%
#checking for missing values
df_concat.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Year                             0
# dtype: int64

# %%
#checking for countries that only got surveyed once:
df_concat["Country"].value_counts().loc[lambda x :x<2]
# Out:
# Somaliland region    1
# Oman                 1
# Puerto Rico          1
# Djibouti             1
# Somaliland Region    1
# Name: Country, dtype: int64

# %%
#renaming Somaliland region to Somaliland Region
df_concat=df_concat.replace(["Somaliland region"], "Somaliland Region")

# %%
df_concat["Country"].value_counts().loc[lambda x : x<2]
# Out:
# Oman           1
# Puerto Rico    1
# Djibouti       1
# Name: Country, dtype: int64

# %%
#dropping 3 countries from the dataset, as there are not enough data to compare them to 
# and they amount to less than 5% of the whole dataset (0,3%)
df_drop =df_concat.drop(df_concat[df_concat["Country"].isin(["Oman","Puerto Rico","Djibouti"])].index)

# %%
df_drop["Country"].value_counts().loc[lambda x : x<2]
# Out:
# Series([], Name: Country, dtype: int64)

# %%
# looking for mixed type data columns
for col in df_drop.columns.tolist():
    weird = (df_drop[[col]].applymap(type)!=df_drop[[col]].iloc[0].apply(type)).any(axis=1)
if len (df_drop[weird])>0:
    print(col)

# %% [markdown]
# No mixed type data found.

# %%
#exporting df_concat
df_drop.to_pickle(os.path.join(path, "Prepared Data", "df2015_2019_dropped.pkl"))

# %% [markdown]
# # 03 EDA

# %%
df_drop.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      763.000000       763.000000                763.000000  763.000000
# mean        79.246396         5.364510                  0.910665    1.076753
# std         44.967146         1.123326                  0.403930    0.328814
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         41.000000         4.510500                  0.604024    0.868716
# 50%         79.000000         5.303000                  0.975000    1.123236
# 75%        117.500000         6.167500                  1.229215    1.324055
# max        158.000000         7.769000                  1.870766    1.644000
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                763.000000  763.000000                     763.000000
# mean                   0.609808    0.410371                       0.123595
# ...

# %%
#installing sweetviz to create a shortcut EDA in html format:

# !pip install sweetviz

# %%
import sweetviz

# %%
report = sweetviz.analyze([df_drop, "Happiness"], target_feat = "Happiness Score")
report.show_html("report.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#manually performing EDA by creating a heat map first:

import seaborn as sns
import matplotlib.pyplot as plt

corr = df_drop.corr()
fig, ax = plt.subplots(figsize = (14, 10))
 
sns.heatmap(ax = ax, \
            data = corr, \
            annot = True, \
            cmap = "coolwarm", \
            vmin = -1, vmax= 1, center = 0)
 
ax.set_title("Correlation Matrix of World Happiness")
 
plt.show()
# Out:
# C:\Users\Anwender\AppData\Local\Temp\ipykernel_5092\4041328177.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_drop.corr()

# %% [markdown]
# Judging from this heatmap, the happiness score is strongly correlated to the Economy, followed by Health, Family, Freedom and Trust respectively. The happiness score does not seem to have a correlation to Generosity and it does not seem to correlate to the Year either, therefore I will be dismissing these factors in the following analysis.

# %%
# plotting pairwise relationships in the df_concat

sns.pairplot(df_drop)

# %% [markdown]
# With the incorporated histograms for each column, we can see that the values for the Happiness Score are normally distributed. The values in the Economy column are slightly left-skewed, whereas the values for columns like Family, Health and Freedom are visibly more left-skewed. The values of columns like Trust and Generosity are right-skewed.

# %%
# looking at top 10 countries for Economy in 2019

ax = sns.barplot(x="Economy (GDP per Capita)", y="Country", data=df19.nlargest(10, "Economy (GDP per Capita)"),
            palette = sns.color_palette("mako", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel("Economy", fontsize=12);
plt.ylabel("Country", fontsize=12);
plt.title("Top 10 Countries with Highest Economy Score in 2019", fontsize=14)
plt.show()

# %%
#looking at the whole df

ax = sns.barplot(x="Economy (GDP per Capita)", y="Country", data=df_drop.nlargest(10, "Economy (GDP per Capita)"),
            palette = sns.color_palette("mako", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel("Economy", fontsize=12);
plt.ylabel("Country", fontsize=12);
plt.title("Countries with Highest Economy Score", fontsize=14)
plt.show()

# %% [markdown]
# This bar chart shows that for the df_concat, only these 5 countries achieved the highest Economy scores.

# %%
# looking at top 10 countries for Family in 2019

ax = sns.barplot(x="Family", y="Country", data=df19.nlargest(10, "Family"),
            palette = sns.color_palette("mako", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel("Family", fontsize=12);
plt.ylabel("Country", fontsize=12);
plt.title("Top 10 Countries with Highest Family Score in 2019", fontsize=14)
plt.show()

# %%
# looking at countries with the highest scores for Family in whole df

ax = sns.barplot(x="Family", y="Country", data=df_drop.nlargest(10, "Family"),
            palette = sns.color_palette("mako", 10))

for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel("Family", fontsize=12);
plt.ylabel("Country", fontsize=12);
plt.title("Countries with Highest Family Score", fontsize=14)
plt.show()

# %%
# looking at top 10 countries with highest Freedom score in 2019:
ax = sns.barplot(x="Freedom", y="Country", data = df19.nlargest(10, "Freedom"),
                 palette = sns.color_palette("mako", 10))
for label in ax.containers:
    ax.bar_label(label, fontsize=7)
plt.xlabel("Freedom", fontsize=12);
plt.ylabel("Country", fontsize=12);
plt.title("Top 10 Countres with highest Freedom score in 2019", fontsize=14)
plt.show()

# %%
# looking at overall highest Freedom scores in df_concat:

ax = sns.barplot(x="Freedom", y="Country", data=df_drop.nlargest(10,"Freedom"),
                palette=sns.color_palette("mako",10))
for label in ax.containers:
    ax.bar_label(label,fontsize=7)
plt.xlabel("Freedom",fontsize=12);
plt.ylabel("Country",fontsize=12);
plt.title("Countries with highest Freedom ratings",fontsize=14)
plt.show()

# %%
# looking at top 10 countries with highest Health scores in 2019:
ax = sns.barplot(x="Health (Life Expectancy)",y="Country",data=df19.nlargest(10,"Health (Life Expectancy)"),
                palette=sns.color_palette("mako",10))
for label in ax.containers:
    ax.bar_label(label,fontsize=7)
plt.xlabel("Health",fontsize=12)
plt.ylabel("Country",fontsize=12)
plt.title("Top 10 countries with highest Health scores in 2019",fontsize=14)
plt.show()

# %%
#looking at overall highest Health scores:
ax = sns.barplot(x="Health (Life Expectancy)",y="Country", data=df_drop.nlargest(10,"Health (Life Expectancy)"),
                palette=sns.color_palette("mako",10))
for label in ax.containers:
    ax.bar_label(label,fontsize=7)
plt.xlabel("Health",fontsize=12)
plt.ylabel("Country",fontsize=12)
plt.title("Countries with overall highest Health scores",fontsize=14)
plt.show()

# %% [markdown]
# Incidentally, the overall countries with the highest Health scores are the same countries that came out as the top 10 in 2019.

# %%
df_drop.nlargest(10,"Health (Life Expectancy)")
# Out:
#         Country                     Region  Happiness Rank  Happiness Score  \
# 33    Singapore          Southeastern Asia              34            6.262
# 75    Hong Kong               Eastern Asia              76            5.430
# 57        Japan               Eastern Asia              58            5.886
# 29        Spain             Western Europe              30            6.354
# 5   Switzerland             Western Europe               6            7.480
# 23       France             Western Europe              24            6.592
# 48       Cyprus             Western Europe              49            6.046
# 8        Canada              North America               9            7.278
# 35        Italy             Western Europe              36            6.223
# 10    Australia  Australia and New Zealand              11            7.228
#
#     Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...
